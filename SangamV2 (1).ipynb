# 33744  2017-05-17 21:00:00       None                  269        85
# 33745  2017-05-17 21:00:00       None                   74        85
# 33746  2017-05-17 22:00:00       None                   81        70
# 33747  2017-05-17 22:00:00       None                  138        70
# 33748  2017-05-17 23:00:00       None                  229        66
# 33749  2017-05-17 23:00:00       None                  140        63
#
#        wind_speed  wind_direction  visibility_in_miles  dew_point  \
# 0               2             329                    1          1
# 1               3             330                    1          1
# 2               3             329                    2          2
# 3               3             329                    5          5
# 4               3             329                    7          7
# 5               3             328                    6          6
# 6               3             328                    7          7
# 7               3             327                    7          7
# 8               3             327                    6          6
# 9               3             326                    3          3
# 10              3             326                    8          8
# 11              3             326                    5          5
# 12              4             325                    4          4
# 13              4             325                    7          7
# 14              4             324                    5          5
# 15              4             324                    2          2
# 16              4             324                    6          6
# 17              4             323                    1          1
# 18              4             323                    7          7
# 19              4             322                    4          4
# 20              4             322                    3          3
# 21              4             322                    4          4
# 22              4             321                    4          4
# 23              4             321                    4          4
# 24              4             320                    3          3
# 25              4             320                    1          1
# 26              4             320                    4          4
# 27              5             350                    3          3
# 28              4             320                    1          1
# 29              5             330                    4          4
# ...           ...             ...                  ...        ...
# 33720           2             315                    7          7
# 33721           2             315                    6          6
# 33722           2             340                    8          8
# 33723           2             340                    9          9
# 33724           1             180                    6          6
# 33725           1             315                    6          6
# 33726           3             341                    1          1
# 33727           3             341                    1          1
# 33728           2             335                    7          7
# 33729           1             318                    5          5
# 33730           1             333                    6          6
# 33731           2             334                    6          6
# 33732           2             334                    4          4
# 33733           2             334                    2          2
# 33734           2             337                    8          8
# 33735           2             337                    4          4
# 33736           2             337                    2          2
# 33737           1             321                    4          4
# 33738           1             321                    8          8
# 33739           1             321                    3          3
# 33740           1             326                    5          5
# 33741           1             326                    6          6
# 33742           1             326                    1          1
# 33743           1             328                    8          8
# 33744           1             328                    5          5
# 33745           1             328                    7          7
# 33746           1              24                    2          2
# 33747           1              24                    1          1
# 33748           1              42                    6          6
# 33749           1              27                    8          8
#
#        temperature  rain_p_h  snow_p_h  clouds_all  weather_type  \
# 0           288.28       0.0       0.0          40        Clouds
# 1           289.36       0.0       0.0          75        Clouds
# 2           289.58       0.0       0.0          90        Clouds
# 3           290.13       0.0       0.0          90        Clouds
# 4           291.14       0.0       0.0          75        Clouds
# 5           291.72       0.0       0.0           1         Clear
# 6           293.17       0.0       0.0           1         Clear
# 7           293.86       0.0       0.0           1         Clear
# 8           294.14       0.0       0.0          20        Clouds
# 9           293.10       0.0       0.0          20        Clouds
# 10          290.97       0.0       0.0          20        Clouds
# 11          289.38       0.0       0.0           1         Clear
# 12          288.61       0.0       0.0           1         Clear
# 13          287.16       0.0       0.0           1         Clear
# 14          285.45       0.0       0.0           1         Clear
# 15          284.63       0.0       0.0           1         Clear
# 16          283.47       0.0       0.0           1         Clear
# 17          281.18       0.0       0.0           1         Clear
# 18          281.09       0.0       0.0           1         Clear
# 19          279.53       0.0       0.0           1         Clear
# 20          278.62       0.0       0.0           1         Clear
# 21          278.23       0.0       0.0           1         Clear
# 22          278.12       0.0       0.0           1         Clear
# 23          282.48       0.0       0.0           1         Clear
# 24          291.97       0.0       0.0           1         Clear
# 25          293.23       0.0       0.0           1         Clear
# 26          294.31       0.0       0.0           1         Clear
# 27          295.17       0.0       0.0           1         Clear
# 28          295.13       0.0       0.0           1         Clear
# 29          293.66       0.0       0.0          20        Clouds
# ...            ...       ...       ...         ...           ...
# 33720       290.22       0.0       0.0          90          Mist
# 33721       290.22       0.0       0.0          90       Drizzle
# 33722       291.02       0.0       0.0          90          Rain
# 33723       291.75       0.0       0.0          90          Rain
# 33724       291.75       0.0       0.0          90          Mist
# 33725       292.09       0.0       0.0          90          Rain
# 33726       292.09       0.0       0.0          90       Drizzle
# 33727       292.62       0.0       0.0          90          Rain
# 33728       293.15       0.0       0.0          40          Rain
# 33729       292.75       0.0       0.0          90          Rain
# 33730       292.75       0.0       0.0          90          Mist
# 33731       292.09       0.0       0.0          90          Rain
# 33732       292.09       0.0       0.0          90          Mist
# 33733       291.35       0.0       0.0          90          Rain
# 33734       291.35       0.0       0.0          90          Mist
# 33735       291.35       0.0       0.0          90       Drizzle
# 33736       291.35       0.0       0.0          90  Thunderstorm
# 33737       290.56       0.0       0.0          90       Drizzle
# 33738       290.56       0.0       0.0          90  Thunderstorm
# 33739       290.56       0.0       0.0          90          Rain
# 33740       288.89       0.0       0.0          90  Thunderstorm
# 33741       288.89       0.0       0.0          90          Rain
# 33742       288.89       0.0       0.0          90          Mist
# 33743       287.88       0.0       0.0          90  Thunderstorm
# 33744       287.88       0.0       0.0          90          Rain
# 33745       287.88       0.0       0.0          90          Mist
# 33746       286.95       0.0       0.0          90          Rain
# 33747       286.95       0.0       0.0          90          Mist
# 33748       285.75       0.0       0.0          90          Rain
# 33749       285.75       0.0       0.0          90          Mist
#
#            weather_description  traffic_volume
# 0             scattered clouds            5545
# 1                broken clouds            4516
# 2              overcast clouds            4767
# 3              overcast clouds            5026
# 4                broken clouds            4918
# 5                 sky is clear            5181
# 6                 sky is clear            5584
# 7                 sky is clear            6015
# 8                   few clouds            5791
# 9                   few clouds            4770
# 10                  few clouds            3539
# 11                sky is clear            2784
# 12                sky is clear            2361
# 13                sky is clear            1529
# 14                sky is clear             963
# 15                sky is clear             506
# 16                sky is clear             321
# 17                sky is clear             273
# 18                sky is clear             367
# 19                sky is clear             814
# 20                sky is clear            2718
# 21                sky is clear            5673
# 22                sky is clear            6511
# 23                sky is clear            5471
# 24                sky is clear            5097
# 25                sky is clear            4887
# 26                sky is clear            5337
# 27                sky is clear            5692
# 28                sky is clear            6137
# 29                  few clouds            4623
# ...                        ...             ...
# 33720                     mist            4517
# 33721  light intensity drizzle            4517
# 33722            moderate rain            4666
# 33723    proximity shower rain            4990
# 33724                     mist            4990
# 33725    proximity shower rain            4789
# 33726  light intensity drizzle            4789
# 33727    proximity shower rain            5185
# 33728    proximity shower rain            5590
# 33729            moderate rain            6426
# 33730                     mist            6426
# 33731            moderate rain            5763
# 33732                     mist            5763
# 33733            moderate rain            4864
# 33734                     mist            4864
# 33735  light intensity drizzle            4864
# 33736   proximity thunderstorm            4864
# 33737  light intensity drizzle            3136
# 33738   proximity thunderstorm            3136
# 33739               light rain            3136
# 33740   proximity thunderstorm            2733
# 33741     heavy intensity rain            2733
# 33742                     mist            2733
# 33743   proximity thunderstorm            2348
# 33744               light rain            2348
# 33745                     mist            2348
# 33746     heavy intensity rain            2194
# 33747                     mist            2194
# 33748     heavy intensity rain            1328
# 33749                     mist            1328
#
# [33750 rows x 15 columns]

# %%
print(traffic.shape)
# Out:
# (33750, 15)

# %%
traffic["is_holiday"].value_counts()
# Out:
# None                         33707
# Thanksgiving Day                 5
# Christmas Day                    5
# New Years Day                    5
# Washingtons Birthday             4
# Veterans Day                     4
# Columbus Day                     4
# Labor Day                        4
# Independence Day                 3
# Memorial Day                     3
# State Fair                       3
# Martin Luther King Jr Day        3
# Name: is_holiday, dtype: int64

# %%
#label encoding weather_type to numerical
traffic.weather_type=le.fit_transform(traffic.weather_type)

# %%
traffic.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2012-10-02 09:00:00       None                  121        89           2
# 1  2012-10-02 10:00:00       None                  178        67           3
# 2  2012-10-02 11:00:00       None                  113        66           3
# 3  2012-10-02 12:00:00       None                   20        66           3
# 4  2012-10-02 13:00:00       None                  281        65           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
# 3             329                    5          5       290.13       0.0
# 4             329                    7          7       291.14       0.0
#
#    snow_p_h  clouds_all  weather_type weather_description  traffic_volume
# 0       0.0          40             1    scattered clouds            5545
# 1       0.0          75             1       broken clouds            4516
# 2       0.0          90             1     overcast clouds            4767
# 3       0.0          90             1     overcast clouds            5026
# 4       0.0          75             1       broken clouds            4918

# %%
list(le.classes_)
# Out:
# ['Clear',
#  'Clouds',
#  'Drizzle',
#  'Fog',
#  'Haze',
#  'Mist',
#  'Rain',
#  'Smoke',
#  'Snow',
#  'Squall',
#  'Thunderstorm']

# %%
#converting is_holiday to numerical; 1 if holiday and 0 otherwise
traffic.loc[traffic['is_holiday']!='None','is_holiday']=1
traffic.loc[traffic['is_holiday']=='None','is_holiday']=0
traffic
# Out:
#                  date_time  is_holiday  air_pollution_index  humidity  \
# 0      2012-10-02 09:00:00           0                  121        89
# 1      2012-10-02 10:00:00           0                  178        67
# 2      2012-10-02 11:00:00           0                  113        66
# 3      2012-10-02 12:00:00           0                   20        66
# 4      2012-10-02 13:00:00           0                  281        65
# 5      2012-10-02 14:00:00           0                   23        65
# 6      2012-10-02 15:00:00           0                  184        64
# 7      2012-10-02 16:00:00           0                  167        64
# 8      2012-10-02 17:00:00           0                  119        63
# 9      2012-10-02 18:00:00           0                  161        63
# 10     2012-10-02 19:00:00           0                  243        62
# 11     2012-10-02 20:00:00           0                  150        62
# 33735       291.35       0.0       0.0          90             2
# 33736       291.35       0.0       0.0          90            10
# 33737       290.56       0.0       0.0          90             2
# 33738       290.56       0.0       0.0          90            10
# 33739       290.56       0.0       0.0          90             6
# 33740       288.89       0.0       0.0          90            10
# 33741       288.89       0.0       0.0          90             6
# 33742       288.89       0.0       0.0          90             5
# 33743       287.88       0.0       0.0          90            10
# 33744       287.88       0.0       0.0          90             6
# 33745       287.88       0.0       0.0          90             5
# 33746       286.95       0.0       0.0          90             6
# 33747       286.95       0.0       0.0          90             5
# 33748       285.75       0.0       0.0          90             6
# 33749       285.75       0.0       0.0          90             5
#
#            weather_description  traffic_volume
# 0             scattered clouds            5545
# 1                broken clouds            4516
# 2              overcast clouds            4767
# 3              overcast clouds            5026
# 4                broken clouds            4918
# 5                 sky is clear            5181
# 6                 sky is clear            5584
# 7                 sky is clear            6015
# 8                   few clouds            5791
# 9                   few clouds            4770
# 10                  few clouds            3539
# 11                sky is clear            2784
# 12                sky is clear            2361
# 13                sky is clear            1529
# 14                sky is clear             963
# 15                sky is clear             506
# 16                sky is clear             321
# 17                sky is clear             273
# 18                sky is clear             367
# 19                sky is clear             814
# 20                sky is clear            2718
# 21                sky is clear            5673
# 22                sky is clear            6511
# 23                sky is clear            5471
# 24                sky is clear            5097
# 25                sky is clear            4887
# 26                sky is clear            5337
# 27                sky is clear            5692
# 28                sky is clear            6137
# 29                  few clouds            4623
# ...                        ...             ...
# 33720                     mist            4517
# 33721  light intensity drizzle            4517
# 33722            moderate rain            4666
# 33723    proximity shower rain            4990
# 33724                     mist            4990
# 33725    proximity shower rain            4789
# 33726  light intensity drizzle            4789
# 33727    proximity shower rain            5185
# 33728    proximity shower rain            5590
# 33729            moderate rain            6426
# 33730                     mist            6426
# 33731            moderate rain            5763
# 33732                     mist            5763
# 33733            moderate rain            4864
# 33734                     mist            4864
# 33735  light intensity drizzle            4864
# 33736   proximity thunderstorm            4864
# 33737  light intensity drizzle            3136
# 33738   proximity thunderstorm            3136
# 33739               light rain            3136
# 33740   proximity thunderstorm            2733
# 33741     heavy intensity rain            2733
# 33742                     mist            2733
# 33743   proximity thunderstorm            2348
# 33744               light rain            2348
# 33745                     mist            2348
# 33746     heavy intensity rain            2194
# 33747                     mist            2194
# 33748     heavy intensity rain            1328
# 33749                     mist            1328
#
# [33750 rows x 15 columns]

# %%
traffic['is_holiday'].value_counts()
# Out:
# 0    33707
# 1       43
# Name: is_holiday, dtype: int64

# %%
traffic['date_time'].describe()
# Out:
# count                   33750
# unique                  28589
# top       2013-05-19 10:00:00
# freq                        6
# Name: date_time, dtype: object

# %%
#splitting date_time into date and time
traffic[['date','time']]=traffic.date_time.str.split(expand=True)
traffic.head()
# Out:
#              date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2012-10-02 09:00:00           0                  121        89           2
# 1  2012-10-02 10:00:00           0                  178        67           3
# 2  2012-10-02 11:00:00           0                  113        66           3
# 3  2012-10-02 12:00:00           0                   20        66           3
# 4  2012-10-02 13:00:00           0                  281        65           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
# 3             329                    5          5       290.13       0.0
# 4             329                    7          7       291.14       0.0
#
#    snow_p_h  clouds_all  weather_type weather_description  traffic_volume  \
# 0       0.0          40             1    scattered clouds            5545
# 1       0.0          75             1       broken clouds            4516
# 2       0.0          90             1     overcast clouds            4767
# 3       0.0          90             1     overcast clouds            5026
# 4       0.0          75             1       broken clouds            4918
#
#          date      time
# 0  2012-10-02  09:00:00
# 1  2012-10-02  10:00:00
# 2  2012-10-02  11:00:00
# 3  2012-10-02  12:00:00
# 4  2012-10-02  13:00:00

# %%
#rearranging date and time to dataframe beginning
col=traffic.columns.tolist()
col=col[-1:]+col[:-1]
col=col[-1:]+col[:-1]
#storing column sequence in col
col
# Out:
# ['date',
#  'time',
#  'date_time',
#  'is_holiday',
#  'air_pollution_index',
#  'humidity',
#  'wind_speed',
#  'wind_direction',
#  'visibility_in_miles',
#  'dew_point',
#  'temperature',
#  'rain_p_h',
#  'snow_p_h',
#  'clouds_all',
#  'weather_type',
#  'weather_description',
#  'traffic_volume']

# %%
#using stored column sequence to rearrange dataframe
traffic=traffic[col]
traffic=traffic.drop('date_time',axis=1)
traffic.head()
# Out:
#          date      time  is_holiday  air_pollution_index  humidity  \
# 0  2012-10-02  09:00:00           0                  121        89
# 1  2012-10-02  10:00:00           0                  178        67
# 2  2012-10-02  11:00:00           0                  113        66
# 3  2012-10-02  12:00:00           0                   20        66
# 4  2012-10-02  13:00:00           0                  281        65
#
#    wind_speed  wind_direction  visibility_in_miles  dew_point  temperature  \
# 0           2             329                    1          1       288.28
# 1           3             330                    1          1       289.36
# 2           3             329                    2          2       289.58
# 3           3             329                    5          5       290.13
# 4           3             329                    7          7       291.14
#
#    rain_p_h  snow_p_h  clouds_all  weather_type weather_description  \
# 0       0.0       0.0          40             1    scattered clouds
# 1       0.0       0.0          75             1       broken clouds
# 2       0.0       0.0          90             1     overcast clouds
# 3       0.0       0.0          90             1     overcast clouds
# 4       0.0       0.0          75             1       broken clouds
#
#    traffic_volume
# 0            5545
# 1            4516
# 2            4767
# 3            5026
# 4            4918

# %%
#converting date to datetime type to get days from it further on
traffic['date']= pd.to_datetime(traffic['date'])

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33750 entries, 0 to 33749
# Data columns (total 16 columns):
# date                   33750 non-null datetime64[ns]
# time                   33750 non-null object
# is_holiday             33750 non-null int64
# air_pollution_index    33750 non-null int64
# humidity               33750 non-null int64
# wind_speed             33750 non-null int64
# wind_direction         33750 non-null int64
# visibility_in_miles    33750 non-null int64
# dew_point              33750 non-null int64
# temperature            33750 non-null float64
# rain_p_h               33750 non-null float64
# snow_p_h               33750 non-null float64
# clouds_all             33750 non-null int64
# weather_type           33750 non-null int32
# weather_description    33750 non-null object
# traffic_volume         33750 non-null int64
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(9), object(2)
# memory usage: 4.0+ MB

# %%
traffic1=traffic
traffic1.head()
# Out:
#         date      time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0 2012-10-02  09:00:00           0                  121        89           2
# 1 2012-10-02  10:00:00           0                  178        67           3
# 2 2012-10-02  11:00:00           0                  113        66           3
# 3 2012-10-02  12:00:00           0                   20        66           3
# 4 2012-10-02  13:00:00           0                  281        65           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
# 3             329                    5          5       290.13       0.0
# 4             329                    7          7       291.14       0.0
#
#    snow_p_h  clouds_all  weather_type weather_description  traffic_volume
# 0       0.0          40             1    scattered clouds            5545
# 1       0.0          75             1       broken clouds            4516
# 2       0.0          90             1     overcast clouds            4767
# 3       0.0          90             1     overcast clouds            5026
# 4       0.0          75             1       broken clouds            4918

# %%
#using only days from the dates; converting days to numerical equivalents
traffic1['date']=traffic1['date'].dt.weekday
traffic1['date']=traffic1['date'].astype(int)

# %%
traffic1.head()
# Out:
#    date      time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0     1  09:00:00           0                  121        89           2
# 1     1  10:00:00           0                  178        67           3
# 2     1  11:00:00           0                  113        66           3
# 3     1  12:00:00           0                   20        66           3
# 4     1  13:00:00           0                  281        65           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
# 3             329                    5          5       290.13       0.0
# 4             329                    7          7       291.14       0.0
#
#    snow_p_h  clouds_all  weather_type weather_description  traffic_volume
# 0       0.0          40             1    scattered clouds            5545
# 1       0.0          75             1       broken clouds            4516
# 2       0.0          90             1     overcast clouds            4767
# 3       0.0          90             1     overcast clouds            5026
# 4       0.0          75             1       broken clouds            4918

# %%
#dropping the :00 from time since redundant and inhibits operations
traffic1['time']=traffic1['time'].str.replace(':00','')
traffic1['time']=traffic1['time'].astype(int)
traffic1.head()
# Out:
#    date  time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0     1     9           0                  121        89           2
# 1     1    10           0                  178        67           3
# 2     1    11           0                  113        66           3
# 3     1    12           0                   20        66           3
# 4     1    13           0                  281        65           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
# 3             329                    5          5       290.13       0.0
# 4             329                    7          7       291.14       0.0
#
#    snow_p_h  clouds_all  weather_type weather_description  traffic_volume
# 0       0.0          40             1    scattered clouds            5545
# 1       0.0          75             1       broken clouds            4516
# 2       0.0          90             1     overcast clouds            4767
# 3       0.0          90             1     overcast clouds            5026
# 4       0.0          75             1       broken clouds            4918

# %%
traffic1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33750 entries, 0 to 33749
# Data columns (total 16 columns):
# date                   33750 non-null int32
# time                   33750 non-null int32
# is_holiday             33750 non-null int64
# air_pollution_index    33750 non-null int64
# humidity               33750 non-null int64
# wind_speed             33750 non-null int64
# wind_direction         33750 non-null int64
# visibility_in_miles    33750 non-null int64
# dew_point              33750 non-null int64
# temperature            33750 non-null float64
# rain_p_h               33750 non-null float64
# snow_p_h               33750 non-null float64
# clouds_all             33750 non-null int64
# weather_type           33750 non-null int32
# weather_description    33750 non-null object
# traffic_volume         33750 non-null int64
# dtypes: float64(3), int32(3), int64(9), object(1)
# memory usage: 3.7+ MB

# %%
#converting all sundays to holidays in is_holiday
traffic1.loc[traffic1['date']=='6','is_holiday']=1
# Out:
# E:\Softwares\Ana\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
#transferring dataframe to traffic2 for dropping weather_description; traffic1 to be worked on later
traffic2=traffic1
traffic2=traffic2.drop(['weather_description'],axis=1)
traffic2.head()
# Out:
#    date  time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0     1     9           0                  121        89           2
# 1     1    10           0                  178        67           3
# 2     1    11           0                  113        66           3
# 3     1    12           0                   20        66           3
# 4     1    13           0                  281        65           3
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0             329                    1          1       288.28       0.0
# 1             330                    1          1       289.36       0.0
# 2             329                    2          2       289.58       0.0
# 3             329                    5          5       290.13       0.0
# 4             329                    7          7       291.14       0.0
#
#    snow_p_h  clouds_all  weather_type  traffic_volume
# 0       0.0          40             1            5545
# 1       0.0          75             1            4516
# 2       0.0          90             1            4767
# 3       0.0          90             1            5026
# 4       0.0          75             1            4918

# %%
traffic2[['temperature','rain_p_h','snow_p_h']]=traffic2[['temperature','rain_p_h','snow_p_h']].astype(int)
traffic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33750 entries, 0 to 33749
# Data columns (total 15 columns):
# date                   33750 non-null int32
# time                   33750 non-null int32
# is_holiday             33750 non-null int64
# air_pollution_index    33750 non-null int64
# humidity               33750 non-null int64
# wind_speed             33750 non-null int64
# wind_direction         33750 non-null int64
# visibility_in_miles    33750 non-null int64
# dew_point              33750 non-null int64
# temperature            33750 non-null int32
# rain_p_h               33750 non-null int32
# snow_p_h               33750 non-null int32
# clouds_all             33750 non-null int64
# weather_type           33750 non-null int32
# traffic_volume         33750 non-null int64
# dtypes: int32(6), int64(9)
# memory usage: 3.1 MB

# %%
x_train,x_test,y_train,y_test=train_test_split(traffic2.drop('traffic_volume',axis=1),traffic2['traffic_volume'],test_size=0.2,random_state=5)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
prd=lr.predict(x_test)

# %%
lr.score(x_test,y_test)
# Out:
# 0.15925718423022395

# %%
r_sq=r2_score(y_test,prd)
r_sq
# Out:
# 0.15925718423022395

# %% [markdown]
# A 2% to 15% jump is good, but far from acceptable. I'm gonna work on the weather description column instead of dropping it, as well as simplifying most other data. Do discuss any ideas or plans-of-action on the group.

# %% [markdown]
# ##### PCA for Feature Selection

# %%
#configuring characters; no of components = 2
pca.n_components=2
pca_data=pca.fit_transform(traffic2)

#pca_reduced will contain the 2d projects of simple data
print('Shape of pca_reduced.shape: ',pca_data.shape)
# Out:
# Shape of pca_reduced.shape:  (33750, 2)

# %%
data=np.vstack((pca_data.T,traffic2['traffic_volume'])).T    #T for tranpose, without which h-stack needs to be used
trafficpca=pd.DataFrame(data,columns=('Col1','Col2','Labels'))
trafficpca.head()
# Out:
#           Col1        Col2  Labels
# 0  2304.975597 -127.486083  5545.0
# 1  1275.994001 -129.843349  4516.0
# 2  1527.015318 -128.667482  4767.0
# 3  1786.031664 -128.273184  5026.0
# 4  1677.981449 -128.781965  4918.0

# %% [markdown]
# Applying linear regression on the PCA reduced dataframe.

# %%
x_train1,x_test1,y_train1,y_test1=train_test_split(trafficpca.drop('Labels',axis=1),trafficpca['Labels'],test_size=0.1,random_state=5)

# %%
lr.fit(x_train1,y_train1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
prdpca=lr.predict(x_test1)

# %%
prdpca
# Out:
# array([4865.01062702,  454.03009987, 3215.03156189, ...,  322.93097608,
#        4200.02724328, 2686.95658795])

# %%
prdpca.shape
# Out:
# (3375,)

# %%
lr.score(x_test1,y_test1)
# Out:
# 0.9999999997238078

# %%
r_sq1=r2_score(y_test1,prdpca)
r_sq1
# Out:
# 0.9999999997238079

# %%
accuracy_score(y_test1,prdpca.round())
# Out:
# 1.0

# %%
custom_x=[4,9,0,121,89,2,329,1,1,288,0,0,40,1]

# %%
#For test data
traffic_test=pd.read_csv("C:/Users/suraj/Downloads/Sangam 2019/DataSets/Test.csv")
traffic_test.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00       None                   73        63           1
# 1  2017-05-18 00:00:00       None                  251        63           1
# 2  2017-05-18 00:00:00       None                   75        56           1
# 3  2017-05-18 01:00:00       None                   98        56           1
# 4  2017-05-18 01:00:00       None                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# 0         0          90         Rain            moderate rain
# 1         0          90         Mist                     mist
# 2         0          90      Drizzle  light intensity drizzle
# 3         0          90         Rain     heavy intensity rain
# 4         0          90         Mist                     mist

# %%
#label encoding weather_type to numerical
traffic_test.weather_type=le.fit_transform(traffic_test.weather_type)

# %%
#converting is_holiday to numerical; 1 if holiday and 0 otherwise
traffic_test.loc[traffic_test['is_holiday']!='None','is_holiday']=1
traffic_test.loc[traffic_test['is_holiday']=='None','is_holiday']=0
traffic_test.head()
# Out:
#              date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00           0                   73        63           1
# 1  2017-05-18 00:00:00           0                  251        63           1
# 2  2017-05-18 00:00:00           0                   75        56           1
# 3  2017-05-18 01:00:00           0                   98        56           1
# 4  2017-05-18 01:00:00           0                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all  weather_type      weather_description
# 0         0          90             6            moderate rain
# 1         0          90             5                     mist
# 2         0          90             2  light intensity drizzle
# 3         0          90             6     heavy intensity rain
# 4         0          90             5                     mist

# %%
#splitting date_time into date and time
traffic_test[['date','time']]=traffic_test.date_time.str.split(expand=True)
traffic_test.head()
# Out:
#              date_time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00           0                   73        63           1
# 1  2017-05-18 00:00:00           0                  251        63           1
# 2  2017-05-18 00:00:00           0                   75        56           1
# 3  2017-05-18 01:00:00           0                   98        56           1
# 4  2017-05-18 01:00:00           0                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all  weather_type      weather_description        date  \
# 0         0          90             6            moderate rain  2017-05-18
# 1         0          90             5                     mist  2017-05-18
# 2         0          90             2  light intensity drizzle  2017-05-18
# 3         0          90             6     heavy intensity rain  2017-05-18
# 4         0          90             5                     mist  2017-05-18
#
#        time
# 0  00:00:00
# 1  00:00:00
# 2  00:00:00
# 3  01:00:00
# 4  01:00:00

# %%
#rearranging date and time to dataframe beginning
col=traffic_test.columns.tolist()
col=col[-1:]+col[:-1]
col=col[-1:]+col[:-1]
#storing column sequence in col
col
# Out:
# ['date',
#  'time',
#  'date_time',
#  'is_holiday',
#  'air_pollution_index',
#  'humidity',
#  'wind_speed',
#  'wind_direction',
#  'visibility_in_miles',
#  'dew_point',
#  'temperature',
#  'rain_p_h',
#  'snow_p_h',
#  'clouds_all',
#  'weather_type',
#  'weather_description']

# %%
#using stored column sequence to rearrange dataframe
traffic_test=traffic_test[col]
traffic_test=traffic_test.drop('date_time',axis=1)
traffic_test.head()
# Out:
#          date      time  is_holiday  air_pollution_index  humidity  \
# 0  2017-05-18  00:00:00           0                   73        63
# 1  2017-05-18  00:00:00           0                  251        63
# 2  2017-05-18  00:00:00           0                   75        56
# 3  2017-05-18  01:00:00           0                   98        56
# 4  2017-05-18  01:00:00           0                  283        56
#
#    wind_speed  wind_direction  visibility_in_miles  dew_point  temperature  \
# 0           1              27                    4          4       285.15
# 1           1              27                    4          4       285.15
# 2           1               0                    1          1       285.15
# 3           1             351                    2          2       284.79
# 4           1             351                    1          1       284.79
#
#    rain_p_h  snow_p_h  clouds_all  weather_type      weather_description
# 0       0.0         0          90             6            moderate rain
# 1       0.0         0          90             5                     mist
# 2       0.0         0          90             2  light intensity drizzle
# 3       0.0         0          90             6     heavy intensity rain
# 4       0.0         0          90             5                     mist

# %%
#converting date to datetime type to get days from it further on
traffic_test['date']= pd.to_datetime(traffic_test['date'])

# %%
traffic_test1=traffic_test
traffic_test1.head()
# Out:
#         date      time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0 2017-05-18  00:00:00           0                   73        63           1
# 1 2017-05-18  00:00:00           0                  251        63           1
# 2 2017-05-18  00:00:00           0                   75        56           1
# 3 2017-05-18  01:00:00           0                   98        56           1
# 4 2017-05-18  01:00:00           0                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all  weather_type      weather_description
# 0         0          90             6            moderate rain
# 1         0          90             5                     mist
# 2         0          90             2  light intensity drizzle
# 3         0          90             6     heavy intensity rain
# 4         0          90             5                     mist

# %%
#using only days from the dates; converting days to numerical equivalents
traffic_test1['date']=traffic_test1['date'].dt.weekday
traffic_test1['date']=traffic_test1['date'].astype(int)

# %%
#dropping the :00 from time since redundant and inhibits operations
traffic_test1['time']=traffic_test1['time'].str.replace(':00','')
traffic_test1['time']=traffic_test1['time'].astype(int)
traffic_test1.head()
# Out:
#    date  time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0     3     0           0                   73        63           1
# 1     3     0           0                  251        63           1
# 2     3     0           0                   75        56           1
# 3     3     1           0                   98        56           1
# 4     3     1           0                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all  weather_type      weather_description
# 0         0          90             6            moderate rain
# 1         0          90             5                     mist
# 2         0          90             2  light intensity drizzle
# 3         0          90             6     heavy intensity rain
# 4         0          90             5                     mist

# %%
#converting all sundays to holidays in is_holiday
traffic_test1.loc[traffic_test1['date']=='6','is_holiday']=1
# Out:
# E:\Softwares\Ana\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
#transferring dataframe to traffic2 for dropping weather_description; traffic1 to be worked on later
traffic_test2=traffic_test1
traffic_test2=traffic_test2.drop(['weather_description'],axis=1)
traffic_test2.head()
# Out:
#    date  time  is_holiday  air_pollution_index  humidity  wind_speed  \
# 0     3     0           0                   73        63           1
# 1     3     0           0                  251        63           1
# 2     3     0           0                   75        56           1
# 3     3     1           0                   98        56           1
# 4     3     1           0                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all  weather_type
# 0         0          90             6
# 1         0          90             5
# 2         0          90             2
# 3         0          90             6
# 4         0          90             5

# %%
traffic_test2[['temperature','rain_p_h','snow_p_h']]=traffic_test2[['temperature','rain_p_h','snow_p_h']].astype(int)
traffic_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14454 entries, 0 to 14453
# Data columns (total 14 columns):
# date                   14454 non-null int32
# time                   14454 non-null int32
# is_holiday             14454 non-null int64
# air_pollution_index    14454 non-null int64
# humidity               14454 non-null int64
# wind_speed             14454 non-null int64
# wind_direction         14454 non-null int64
# visibility_in_miles    14454 non-null int64
# dew_point              14454 non-null int64
# temperature            14454 non-null int32
# rain_p_h               14454 non-null int32
# snow_p_h               14454 non-null int32
# clouds_all             14454 non-null int64
# weather_type           14454 non-null int32
# dtypes: int32(6), int64(8)
# memory usage: 1.2 MB

# %%
##PCA on test data
#configuring characters; no of components = 2
pca.n_components=2
pca_data=pca.fit_transform(traffic_test2)

#pca_reduced will contain the 2d projects of simple data
print('Shape of pca_reduced.shape: ',pca_data.shape)
pca_data
# Out:
# Shape of pca_reduced.shape:  (14454, 2)
# array([[ 183.6274397 ,  -77.61087193],
#        [ 180.01054135,  100.34453388],
#        [ 210.37908634,  -75.0687489 ],
#        ...,
#        [ -29.21066818,   18.09189994],
#        [ -56.27272045, -134.48073145],
#        [-117.80200087,  -40.71823822]])

# %%
data=np.vstack((pca_data.T)).T    #T for tranpose, without which h-stack needs to be used
traffic_test_pca=pd.DataFrame(data,columns=('Col1','Col2'))
traffic_test_pca.head()
# Out:
#          Col1        Col2
# 0  183.627440  -77.610872
# 1  180.010541  100.344534
# 2  210.379086  -75.068749
# 3 -140.815930  -59.180670
# 4 -144.574615  125.772537

# %%
prdpca_test=lr.predict(traffic_test_pca)

# %%
prdpca_test.shape
# Out:
# (14454,)

# %%
traffic_test_xl = pd.read_csv("C:/Users/suraj/Downloads/Sangam 2019/DataSets/Test.csv")
traffic_test_xl.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00       None                   73        63           1
# 1  2017-05-18 00:00:00       None                  251        63           1
# 2  2017-05-18 00:00:00       None                   75        56           1
# 3  2017-05-18 01:00:00       None                   98        56           1
# 4  2017-05-18 01:00:00       None                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# 0         0          90         Rain            moderate rain
# 1         0          90         Mist                     mist
# 2         0          90      Drizzle  light intensity drizzle
# 3         0          90         Rain     heavy intensity rain
# 4         0          90         Mist                     mist

# %%
traffic_test_xl['traffic_volume'] = prdpca_test
traffic_test_xl.head()
# Out:
#              date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  2017-05-18 00:00:00       None                   73        63           1
# 1  2017-05-18 00:00:00       None                  251        63           1
# 2  2017-05-18 00:00:00       None                   75        56           1
# 3  2017-05-18 01:00:00       None                   98        56           1
# 4  2017-05-18 01:00:00       None                  283        56           1
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0              27                    4          4       285.15       0.0
# 1              27                    4          4       285.15       0.0
# 2               0                    1          1       285.15       0.0
# 3             351                    2          2       284.79       0.0
# 4             351                    1          1       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description  traffic_volume
# 0         0          90         Rain            moderate rain     3423.689520
# 1         0          90         Mist                     mist     3420.200340
# 2         0          90      Drizzle  light intensity drizzle     3450.442945
# 3         0          90         Rain     heavy intensity rain     3099.259930
# 4         0          90         Mist                     mist     3095.633987

# %%
traffic_test_xl1 = traffic_test_xl[['date_time','traffic_volume']]
traffic_test_xl1.head()
# Out:
#              date_time  traffic_volume
# 0  2017-05-18 00:00:00     3423.689520
# 1  2017-05-18 00:00:00     3420.200340
# 2  2017-05-18 00:00:00     3450.442945
# 3  2017-05-18 01:00:00     3099.259930
# 4  2017-05-18 01:00:00     3095.633987

# %%
#traffic_test_xl1.to_excel('output.xlsx')

# %%
traffic_test_xl1.to_csv('output1.csv',index=False)
